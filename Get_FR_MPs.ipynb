# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ## What I want to do:
#
#     1. Create a data frame of of parliament mebers' names and personal URLs.
#     2. Open each URL to find their Twitter handle.
#     3. Create a data frame with name, party and Twitter handle

# %% [markdown]
# # Locating member URLs on the website

# %%
# Problem: without clicking on a button, the parser doesn't capture the table of politicians
# Solution: click the button and save the html file to computer and open from there

fname = 'deputes_recherche-multicritere.html' #this html file is stored on the same folder of the code file
html_file = open(fname, 'r')
source_code = html_file.read()

# %%
soup = BeautifulSoup(source_code,'html.parser')

# %%
print(soup)
# Out:
#  <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="fr-FR"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8" lang="fr-FR"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9" lang="fr-FR"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="fr-FR"> <!--<![endif]--> <head>
# <meta charset="utf-8"/>
# <title>Recherche multicritère - XVe législature - Assemblée nationale</title>
# <meta content="text/html; charset=utf-8" name="Content-Type"/>
# <meta content="fr-FR" name="Content-language"/>
# <meta content="IE=edge,chrome=1" name="X-UA-Compatible"/>
# <meta content="width=954" name="viewport"/>
# <meta content="Assemblée Nationale" name="author"/>
# <meta content="Assemblée Nationale" name="copyright"/>
# <meta content="Presentation de l'Assemblee nationale, du palais Bourbon, de ses membres (deputes), de son fonctionnement et de son actualite : agenda, travaux en cours (amendements, rapports, commissions, lois), textes et dossiers (legislatifs ou d'actualite)..." name="description"/>
# <meta content="député, hémicycle, Palais Bourbon, Assemblée nationale, parlementaire" name="keywords"/>
# <link href="/extension/common/design/an/images/favicon.ico" rel="shortcut icon" type="image/x-ico"/>
# <script charset="utf-8" src="/extension/common/design/an/javascript/jquery-1.8.3.min.js" type="text/javascript"></script>
# <script type="text/javascript">
#
# (function($) {
#     var _rootUrl = '/', _serverUrl = _rootUrl + 'ezjscore/', _seperator = '@SEPERATOR$',
#         _prefUrl = _rootUrl + 'user/preferences';
#
#     // FIX: Ajax is broken on IE8 / IE7 on jQuery 1.4.x as it's trying to use the broken window.XMLHttpRequest object
#     if ( window.XMLHttpRequest && window.ActiveXObject )
#         $.ajaxSettings.xhr = function() { try { return new window.ActiveXObject('Microsoft.XMLHTTP'); } catch(e) {} };
#
#     // (static) jQuery.ez() uses jQuery.post() (Or jQuery.get() if post paramer is false)
#     //
#     // @param string callArgs
#     // @param object|array|string|false post Optional post values, uses get request if false or undefined
#     // @param function Optional callBack
#     function _ez( callArgs, post, callBack )
#     {
#         callArgs = callArgs.join !== undefined ? callArgs.join( _seperator ) : callArgs;
#         var url = _serverUrl + 'call/';
#         if ( post )
#         {
#             var _token = '', _tokenNode = document.getElementById('ezxform_token_js');
#             if ( _tokenNode ) _token = _tokenNode.getAttribute('title');
#             if ( post.join !== undefined )// support serializeArray() format
#             {
#                 post.push( { 'name': 'ezjscServer_function_arguments', 'value': callArgs } );
#                 post.push( { 'name': 'ezxform_token', 'value': _token } );
#             }
#             else if ( typeof(post) === 'string' )// string
#             {
#                 post += ( post ? '&' : '' ) + 'ezjscServer_function_arguments=' + callArgs + '&ezxform_token=' + _token;
#             }
#             else // object
#             {
#                 post['ezjscServer_function_arguments'] = callArgs;
#                 post['ezxform_token'] = _token;
#             }
#             return $.post( url, post, callBack, 'json' );
#         }
#         return $.get( url + encodeURIComponent( callArgs ), {}, callBack, 'json' );
#     };
#     _ez.url = _serverUrl;
#     _ez.root_url = _rootUrl;
#     _ez.seperator = _seperator;
#     $.ez = _ez;
#
#     $.ez.setPreference = function( name, value )
#     {
#         var param = {'Function': 'set_and_exit', 'Key': name, 'Value': value};
#             _tokenNode = document.getElementById( 'ezxform_token_js' );
#         if ( _tokenNode )
#             param.ezxform_token = _tokenNode.getAttribute( 'title' );
#
#         return $.post( _prefUrl, param );
#     };
#
#     // Method version, for loading response into elements
#     // NB: Does not use json (not possible with .load), so ezjscore/call will return string
#     function _ezLoad( callArgs, post, selector, callBack )
#     {
#         callArgs = callArgs.join !== undefined ? callArgs.join( _seperator ) : callArgs;
#         var url = _serverUrl + 'call/';
#         if ( post )
#         {
#             post['ezjscServer_function_arguments'] = callArgs;
#             post['ezxform_token'] = jQuery('#ezxform_token_js').attr('title');
#         }
#         else
#             url += encodeURIComponent( callArgs );
#
#         return this.load( url + ( selector ? ' ' + selector : '' ), post, callBack );
#     };
#     $.fn.ez = _ezLoad;
# })(jQuery);
#
# </script>
# <script src="/dyn/es6/getvariable.js" type="text/javascript"></script>
# <script src="/extension/common/design/an/javascript/hack-jquery1.8.3.js" type="text/javascript"></script>
# <link href="/extension/common/design/an/stylesheets/bootstrap-2.1.1.min.css" rel="stylesheet" type="text/css">
# <link href="/extension/common/design/an/stylesheets/jquery-ui-1.8.21.custom.css" rel="stylesheet" type="text/css"/>
# <link href="/extension/ezswidl-dashboard/design/standard/stylesheets/datatable_page.css" rel="stylesheet" type="text/css"/>
# <link href="/extension/ezswidl-dashboard/design/standard/stylesheets/datatable_table_jui.css" rel="stylesheet" type="text/css"/>
# <link href="/extension/common/design/an/stylesheets/chosen-0.9.12.css" rel="stylesheet" type="text/css"/>
# <link href="/extension/common/design/an/stylesheets/perfect-scrollbar-0.4.5.min.css" rel="stylesheet" type="text/css"/>
# <link href="/extension/common/design/an/stylesheets/font-awesome-4.5.0.min.css" rel="stylesheet" type="text/css"/>
# <link href="/extension/common/design/an/stylesheets/debug.css" rel="stylesheet" type="text/css"/>
# <link href="/extension/common/design/an/stylesheets/cookies-cnil-banner.css" rel="stylesheet" type="text/css"/>
# <link href="/var/ezflow_site/cache/public/stylesheets/4b3c62ee4483ea9265397bae8c7fb169.css" rel="stylesheet" type="text/css"/>
# <link href="/var/ezflow_site/cache/public/stylesheets/fd31195cfed9738ff26f100d3cf89686.css" rel="stylesheet" type="text/css"/>
# <link href="/var/ezflow_site/cache/public/stylesheets/02320db57121c4e32665659bbf8bb694.css" rel="stylesheet" type="text/css"/>
# <link href="/var/ezflow_site/cache/public/stylesheets/8ea2025f05b4c4e474e3e9f11baeb4f3.css" rel="stylesheet" type="text/css"/>
# <link href="/var/ezflow_site/cache/public/stylesheets/93db2c62f9f074fe7cab9be2b8c707e7.css" rel="stylesheet" type="text/css"/>
# <script src="/extension/common/design/an/javascript/modernizr-2.6.2.min.js"></script>
# <link href="/extension/common/design/an/stylesheets/print.css" media="print" rel="stylesheet"/>
# <link href="/dyn/css/compiled/main_shared.css" rel="stylesheet"/>
# </link></head>
# <body data-legacy-url="https://www2.assemblee-nationale.fr" data-root-url="https://www.assemblee-nationale.fr/">
# <div class="page">
# <div class="new-style-ezpublish">
# <header class="site-header">
# <div class="site-header--top-wrapper">
# <div class="container medium">
# <span class="site-header--top-wrapper--title">Assemblée nationale</span>
# <div class="site-header--top-wrapper--left">
# <div class="lang-selector">
# <div class="lang-selector-current">
# <div class="flag-item" flag-name="fr"></div>
# <i class="an-icons-chevron-bottom"></i>
# </div>
# <div class="new-style-ezpublish lang-selector-list">
# <div class="lang-selector-list--items">
# <div class="flag-item" flag-name="gb">
# <a class="inner" href="/langues/welcome-to-the-english-website-of-the-french-national-assembly"></a>
# </div>
# <div class="flag-item" flag-name="de">
# <a class="inner" href="/langues/willkommen-auf-der-deutschsprachigen-webseite-der-franzoesischen-nationalversammlung"></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="site-header--top-wrapper--right">
# <ul class="social-networks">
# <li>
# <i class="an-icons-twitter"></i>
# <a class="inner" href="https://twitter.com/AssembleeNat" target="_blank"></a>
# </li>
# <li>
# <i class="an-icons-facebook"></i>
# <a class="inner" href="https://fr-fr.facebook.com/AssembleeNationale" target="_blank"></a>
# </li>
# <li>
# <i class="an-icons-instagram"></i>
# <a class="inner" href="https://www.instagram.com/assembleenationale" target="_blank"></a>
# </li>
# <li>
# <i class="an-icons-linkedin2"></i>
# <a class="inner" href="https://fr.linkedin.com/company/assemblee-nationale" target="_blank"></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="hr-flag-large"></div>
# <div class="site-header--logo-wrapper" data-nosnippet="">
# <video autoplay="" class="site-header--logo-wrapper--video" loop="" muted="">
# <source src="/dyn/assets/videos/BackgroundVideo.mp4" type="video/mp4"/>
# </video>
# <div class="site-header--logo-wrapper--logo">
# <a class="inner" href="https://www.assemblee-nationale.fr/"></a>
# </div>
# </div>
# </header>
# <nav id="header-navigation">
# <div id="header-navigation--links">
# <div class="container">
# <ul id="header-main-navigation">
# <li class="">
# <span>Accueil</span>
# <a class="inner" href="https://www.assemblee-nationale.fr/">Accueil</a>
# </li>
# <li class="" data-tab-index="1">
# <span>Vos députés</span>
# </li>
# <li class="" data-tab-index="2">
# <span>Travaux parlementaires</span>
# </li>
# <li data-on="open-general-search" data-tab-index="3">
# <span>
# <img alt="recherche" src="/dyn/assets/images/icons/icon_search.png"/>
# </span>
# </li>
# <li class="" data-tab-index="4">
# <span>Connaître l'Assemblée</span>
# </li>
# <li class="" data-tab-index="5">
# <span>Découvrir les lieux</span>
# </li>
# <li class="" data-tab-index="6">
# <span><i class="an-icons-user"></i>Mon compte</span>
# </li>
# </ul>
# <div id="header-navigation--logo">
# <a class="inner" href="https://www.assemblee-nationale.fr/">Accueil</a>
# </div>
# </div>
# </div>
# <div id="header-navigation--tabs">
# <div class="header-navigation--tab colored-deputes">
# <div class="container">
# <div class="ha-grid with-divider">
# <div class="ha-grid-item size-1">
# <div class="header-navigation--tab--info-box">
# <div class="header-navigation--tab--info-box--title">Vos députés</div>
# <div class="header-navigation--tab--info-box--content">
# <img alt="" src="/dyn/assets/images/icons/icon_deputes.png"/>
# </div>
# </div>
# </div>
# <div class="ha-grid-item size-1">
# <div class="header-navigation--tab--list-box">
# <div class="content">
# <a href="https://presidence.assemblee-nationale.fr/">Le Président</a>
# <a href="https://www.assemblee-nationale.fr/dyn/vos-deputes">577 députés</a>
# <a href="https://www.assemblee-nationale.fr/dyn/les-groupes-politiques">Groupes politiques</a>
# <a href="https://www2.assemblee-nationale.fr/qui/les-elections-legislatives">Élections législatives</a>
# </div>
# </div>
# </div>
# <div class="ha-grid-item size-1"></div>
# </div>
# </div>
# </div>
# <div class="header-navigation--tab colored-travaux">
# <div class="container">
# <div class="ha-grid with-divider">
# <div class="ha-grid-item size-1">
# <div class="header-navigation--tab--info-box">
# <div class="header-navigation--tab--info-box--title">Travaux parlementaires</div>
# <div class="header-navigation--tab--info-box--content">
# <img alt="" src="/dyn/assets/images/icons/icon_travaux.png"/>
# </div>
# </div>
# </div>
# <div class="ha-grid-item size-1">
# <div class="header-navigation--tab--list-box">
# <div class="title">
# <a href="https://www.assemblee-nationale.fr/dyn/seance-publique">Séance publique</a>
# <a href="https://www.assemblee-nationale.fr/dyn/commissions-et-autres-organes">Commissions et autres organes</a>
# <a href="https://www.assemblee-nationale.fr/dyn/europe-et-international">Europe et International</a>
# <a href="https://www2.assemblee-nationale.fr/le-congres-du-parlement">Congrès</a>
# <a href="https://www.assemblee-nationale.fr/dyn/petitions">Pétitions</a>
# </div>
# </div>
# </div>
# <div class="ha-grid-item size-2">
# <div class="header-navigation--tab--list-box">
# <div class="title">
# <a href="https://www.assemblee-nationale.fr/dyn/documents-parlementaires">Documents parlementaires</a>
# </div>
# <div class="content">
# <div class="ha-grid">
# <div class="ha-grid-item size-full">
# <ul>
# <li><a href="https://www2.assemblee-nationale.fr/documents/liste/(type)/projets-loi">Projets de loi</a></li>
# <li><a href="https://www2.assemblee-nationale.fr/documents/liste/(type)/propositions-loi">Propositions de loi</a></li>
# <li><a href="https://www.assemblee-nationale.fr/dyn/15/amendements" id="a-recherche-amendement">Amendements</a></li>
# <li><a href="https://www2.assemblee-nationale.fr/documents/liste/(type)/ta">Textes adoptés</a></li>
# </ul>
# </div>
# <div class="ha-grid-item size-full">
# <ul>
# <li><a href="https://www2.assemblee-nationale.fr/documents/liste/(type)/rapports-information/(legis)/15">Rapports d'information</a></li>
# <li><a href="https://www2.assemblee-nationale.fr/15/autres-commissions/commissions-d-enquete">Rapports d'enquête</a></li>
# <li><a href="https://www2.assemblee-nationale.fr/documents/liste/(type)/rapports-application-loi/(legis)/15">Rapports sur l'application des lois</a></li>
# <li><a href="https://www2.assemblee-nationale.fr/documents/liste/(type)/rapports">Rapports législatifs</a></li>
# </ul>
# </div>
# <div class="ha-grid-item size-full">
# <ul>
# <li><a href="https://www.assemblee-nationale.fr/dyn/15/dossiers">Dossiers législatifs</a></li>
# <li><a href="https://www2.assemblee-nationale.fr/dans-l-hemicycle/budget-et-securite-sociale">Budget et sécurité sociale</a></li>
# <li><a href="https://www2.assemblee-nationale.fr/recherche/questions">Questions écrites et orales</a></li>
# <li><a href="https://www.assemblee-nationale.fr/dyn/15/comptes-rendus/seance">Comptes rendus des débats</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="header-navigation--tab">
# <div class="header-navigation--search-container">
# <div class="container small">
# <div class="search-input general-search-input">
# <div class="search-input--filter">
# <div class="search-input--filter-current colored-grey">
# <span></span>
# </div>
# <div class="search-input--filter-selection colored-grey"></div>
# </div>
# <div class="search-input--input">
# <input alt="Recherche général" placeholder="Recherche général" type="text"/>
# <div class="search-input--result-lists"></div>
# </div>
# <div class="search-input--submit colored-grey">
# <i class="an-icons-search2"></i>
# </div>
# </div> </div>
# </div>
# </div>
# <div class="header-navigation--tab colored-connaissance">
# <div class="container">
# <div class="ha-grid with-divider">
# <div class="ha-grid-item size-1">
# <div class="header-navigation--tab--info-box">
# <div class="header-navigation--tab--info-box--title">Connaître l'Assemblée</div>
# <div class="header-navigation--tab--info-box--content">
# <img alt="" src="/dyn/assets/images/icons/icon_connaissance.png"/>
# </div>
# </div>
# </div>
# <div class="ha-grid-item size-1">
# <div class="header-navigation--tab--list-box">
# <div class="content">
# <a href="https://www.assemblee-nationale.fr/dyn/role-et-pouvoir-de-assemblee">Rôle et pouvoirs de l'Assemblée</a>
# <a href="https://www.assemblee-nationale.fr/dyn/organisation-de-assemblee">Organisation de l'Assemblée</a>
# <div class="header-navigation--tab--list-box--sublinks">
# <ul>
# <li><a href="https://presidence.assemblee-nationale.fr/">Présidence</a></li>
# <li><a href="https://www2.assemblee-nationale.fr/15/la-conference-des-presidents">Conférence des Présidents</a></li>
# <li><a href="https://www2.assemblee-nationale.fr/15/le-bureau-de-l-assemblee-nationale">Bureau</a></li>
# <li><a href="https://www2.assemblee-nationale.fr/15/le-college-des-questeurs">Collège des Questeurs</a></li>
# <li><a href="https://www.assemblee-nationale.fr/infos/services.asp">Services</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="ha-grid-item size-1">
# <div class="header-navigation--tab--list-box">
# <div class="content">
# <a href="https://www2.assemblee-nationale.fr/15/statistiques-de-l-activite-parlementaire">Statistiques et chiffres clés</a>
# <a href="https://www.assemblee-nationale.fr/dyn/transparence-et-deontologie">Transparence et déontologie</a>
# <a href="https://www.assemblee-nationale.fr/dyn/documents-de-reference">
#                                         Documents de référence<span>( Constitution | Règlement de l'Assemblée | Règlement du Congrès ... )</span>
# </a>
# </div>
# </div>
# </div>
# <div class="ha-grid-item size-1">
# <div class="header-navigation--tab--list-box">
# <div class="content">
# <a href="https://www.assemblee-nationale.fr/dyn/histoire">Histoire</a>
# <a href="https://www2.assemblee-nationale.fr/decouvrir-l-assemblee/juniors">Juniors</a>
# <a href="http://archives.assemblee-nationale.fr/">Anciennes législatures</a>
# <a href="https://www.assemblee-nationale.fr/liens.asp">Liens vers les sites publics</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="header-navigation--tab colored-patrimoine">
# <div class="container">
# <div class="ha-grid with-divider">
# <div class="ha-grid-item size-1">
# <div class="header-navigation--tab--info-box">
# <div class="header-navigation--tab--info-box--title">Découvrir les lieux</div>
# <div class="header-navigation--tab--info-box--content">
# <img alt="" src="/dyn/assets/images/icons/icon_connaissance.png"/>
# </div>
# </div>
# </div>
# <div class="ha-grid-item size-1">
# <div class="header-navigation--tab--list-box">
# <div class="content">
# <a href="https://www2.assemblee-nationale.fr/decouvrir-l-assemblee/visiter-l-assemblee-nationale">Visiter l'Assemblée</a>
# <a href="https://www.assemblee-nationale.fr/dyn/visite-virtuelle">Visite virtuelle du palais Bourbon</a>
# <a href="https://www2.assemblee-nationale.fr/informations-pratiques/assister-a-une-seance-publique">Assister à une séance</a>
# <a href="https://www2.assemblee-nationale.fr/decouvrir-l-assemblee/ouverture-de-l-assemblee-aux-chercheurs2">Accès des chercheurs à l’Assemblée</a>
# </div>
# </div>
# </div>
# <div class="ha-grid-item size-1">
# <div class="header-navigation--tab--list-box">
# <div class="content">
# <a href="https://www2.assemblee-nationale.fr/decouvrir-l-assemblee/patrimoine">Patrimoine</a>
# <a href="https://www2.assemblee-nationale.fr/informations-pratiques/bibliotheque-et-archives">Bibliothèque et archives</a>
# <a href="https://www2.assemblee-nationale.fr/informations-pratiques/contacts-et-plan-d-acces">Contacts et plan d'accès</a>
# <a href="https://www.assemblee-nationale.fr/presse/photos.asp">Photos libres de droit </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="header-navigation--tab colored">
# <div class="container">
# <div class="ha-grid with-divider">
# <div class="ha-grid-item size-1">
# <div class="header-navigation--tab--info-box">
# <div class="header-navigation--tab--info-box--title">Connexion &amp; inscription</div>
# <div class="header-navigation--tab--info-box--content">
# <img alt="" src="/dyn/assets/images/icons/icon_account.png"/>
# </div>
# </div>
# </div>
# <div class="ha-grid-item size-2">
# <div class="header-navigation--tab--center-box">
# <div class="ha-grid centered">
# <div class="ha-grid-item size-1-2">
# <div class="form-actions">
# <div class="form-action">
# <div class="button">
# <i class="an-icons-unlock"></i>S'identifier
#                                                         <a class="inner" href="https://secure2.assemblee-nationale.fr/extuser/login">S'identifier</a>
# </div>
# </div>
# <div class="form-action">
# <a href="https://secure2.assemblee-nationale.fr/extuser/forgotpassword">
#                                                         Mot de passe oublié <i class="an-icons-chevron-right"></i>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="ha-grid-item size-1">
# <div class="header-navigation--tab--center-box">
# <div class="registration-link">
# <i class="an-icons-user"></i>
# <span>Vous n'avez pas encore de compte ?</span>
# <br/>
# <b><i class="an-icons-chevron-right"></i> Enregistrez-vous</b>
# <a class="inner" href="https://secure2.assemblee-nationale.fr/extuser/register/2">Enregistrez-vous</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </nav>
# <div id="header-navigation--spacer"></div>
# <div id="site-mask"></div>
# </div>
# <div class="clearfix" id="page-fond">
# <div class="clearfix" id="page">
# <div class="clearfix">
# <section>
# <div class="sans-haut clearfix" id="contenu-page">
# <article>
# <div class="interieur-contenu-principal clearfix">
# <ol class="breadcrumb">
# <li class="sr-only">Vous êtes ici :</li>
# <li><a href="https://www.assemblee-nationale.fr/">Accueil</a></li>
# <li><a href="/deputes" title="Les députés">Les députés</a></li>
# <li class="active">Recherche multicritère</li>
# </ol>
# </div>
# <div class="titre-bandeau-bleu">
# <h1>Recherche multicritère</h1>
# </div>
# <div class="contenu-principal pleine-largeur clearfix">
# <div class="interieur-contenu-principal clearfix">
# <form action="https://www2.assemblee-nationale.fr/deputes/recherche-multicritere" method="POST">
# <h2>Selection des informations à afficher</h2>
# <h4>Informations générales</h4>
# <span><input name="infosGenFiche" type="checkbox" value="fiche"/><span class="spanInfo">Lien fiche</span></span>
# <span><input name="infosGenCiv" type="checkbox" value="civ"/><span class="spanInfo">Civilité</span></span>
# <span><input name="infosGenPrenom" type="checkbox" value="prenom"/><span class="spanInfo">Prénom</span></span>
# <span><input name="infosGenNom" type="checkbox" value="nom"/><span class="spanInfo">Nom</span></span>
# <span><input name="infosGenGroupe" type="checkbox" value="nomGrpPol"/><span class="spanInfo">Groupe</span></span>
# <span><input name="infosGenDept" type="checkbox" value="departement"/><span class="spanInfo">Département d'éléction</span></span>
# <span><input name="infosGenRegion" type="checkbox" value="region"/><span class="spanInfo">Région d'élection</span></span>
# <span><input name="infosGenCirc" type="checkbox" value="numCirco"/><span class="spanInfo">N° circonscription</span></span>
# <span><input name="infosGenComper" type="checkbox" value="nomComPer"/><span class="spanInfo">Commission permanente</span></span>
# <span><input name="infosGenCatSocio" type="checkbox" value="catSocProf"/><span class="spanInfo">Catégorie socioprofessionnelle</span></span>
# <span><input name="infosGenFamSocio" type="checkbox" value="famSocProf"/><span class="spanInfo">Famille socioprofessionnelle</span></span>
# <!--<span><input type="checkbox" name="infosGenCatAge" value="tranche"><span class="spanInfo">Catégorie d'age</span></span>-->
# <span><input name="infosGenAge" type="checkbox" value="age"/><span class="spanInfo">Age</span></span>
# <span><input name="infosGenJob" type="checkbox" value="profession"/><span class="spanInfo">Profession</span></span>
# <span><input name="infosGenDateNaiss" type="checkbox" value="dateNaissance"/><span class="spanInfo">Date de naissance</span></span>
# <h4>Mandats locaux</h4>
# <div>
# <label for="conseilMunicipal" style="text-decoration:underline">Conseil municipal</label> :
# 							<span class="spanMandats"><input name="infosGenConseilMunicipalCommune" type="checkbox" value="nomCommune"/><span class="spanInfo">Commune</span>
# <input name="infosGenConseilMunicipalMandat" type="checkbox" value="mandat"/><span class="spanInfo">Mandat</span></span>
# </div>
# <div>
# <label for="conseilGeneral" style="text-decoration:underline">Conseil départemental</label> :
# 							<span class="spanMandats"><input name="infosGenConseilGeneralDept" type="checkbox" value="nomConsDep"/><span class="spanInfo">Département</span>
# <input name="infosGenConseilGeneralMandat" type="checkbox" value="mandat"/><span class="spanInfo">Mandat</span></span>
# </div>
# <div>
# <label for="conseilRegional" style="text-decoration:underline">Conseil régional</label> :
# 							<span class="spanMandats"><input name="infosGenConseilRegionalRegion" type="checkbox" value="nomConsReg"/><span class="spanInfo">Région</span>
# <input name="infosGenConseilRegionalMandat" type="checkbox" value="mandat"/><span class="spanInfo">Mandat</span></span>
# </div>
# <div>
# <span class="spanMandats"><label for="autreMandat" style="text-decoration:underline">Autre mandat local</label> :
# 							<input name="infosGenAutreMandat" type="checkbox" value="roleAssTOM"/><span class="spanInfo">Assemblée territorial d'outre-mer</span></span>
# </div>
# <h2>Regroupements</h2>
# <p>
# 							1er regroupement :
# 							<select class="inputRegroup" name="regroup">
# <option value="default">Veuillez selectionnez une regroupement</option>
# <option value="commission">Commission</option>
# <option value="departement">Département</option>
# <option value="region">Région</option>
# <option value="groupe">Groupe</option>
# <option value="sexe">Sexe</option>
# <!--<option value="cat_age">Catégorie d'age</option>-->
# <option value="conseil_municipal">Conseil municipal</option>
# <option value="commune">Mandat communal</option>
# <option value="conseil_dept">Conseil départemental</option>
# <option value="mandat_dept">Mandat départemental</option>
# <option value="conseil_regio">Conseil régional</option>
# <option value="mandat_regio">Mandat régional</option>
# <option value="cat_sociopro">Catégorie socioprofessionnelle</option>
# <option value="famille_socioproi">Famille socioprofessionnelle</option>
# </select>
# </p>
# <p>
# 							2e regroupement :
# 							<select class="inputRegroup" name="regroup2">
# <option value="default">Veuillez selectionnez une regroupement</option>
# <option value="commission">Commission</option>
# <option value="departement">Département</option>
# <option value="region">Région</option>
# <option value="groupe">Groupe</option>
# <option value="sexe">Sexe</option>
# <!--<option value="cat_age">Catégorie d'age</option>-->
# <option value="conseil_municipal">Conseil municipal</option>
# <option value="commune">Mandat communal</option>
# <option value="conseil_dept">Conseil départemental</option>
# <option value="mandat_dept">Mandat départemental</option>
# <option value="conseil_regio">Conseil régional</option>
# <option value="mandat_regio">Mandat régional</option>
# <option value="cat_sociopro">Catégorie socioprofessionnelle</option>
# <option value="famille_sociopro">Famille socioprofessionnelle</option>
# </select>
# </p>
# <h2>Critères restrictifs de la recherche</h2>
# <div class="divCritere">
# 							Sexe
# 							<select class="inputCritere" name="critSexe">
# <option value="default">Choisissez une option</option>
# <option value="M.">Homme</option>
# <option value="Mme">Femme</option>
# </select>
# </div>
# <div class="divCritere">
# 							Groupe
# 							<select class="inputCritere" name="critGroupe">
# <option value="default">Choisissez une option</option>
# <option value="LR">LR</option>
# <option value="LaREM">LaREM</option>
# <option value="LT">LT</option>
# <option value="FI">FI</option>
# <option value="SOC">SOC</option>
# <option value="NI">NI</option>
# <option value="Dem">Dem</option>
# <option value="Agir%20ens">Agir ens</option>
# <option value="UDI-I">UDI-I</option>
# <option value="GDR">GDR</option>
# </select>
# </div>
# <div class="divCritere">
# 							Commission
# 							<select class="inputCritere" name="critComper">
# <option value="default">Choisissez une option</option>
# <option value="Finances">Finances</option>
# <option value="Lois">Lois</option>
# <option value="Affaires%20économiques">Affaires économiques</option>
# <option value="Affaires%20étrangères">Affaires étrangères</option>
# <option value="Affaires%20culturelles%20et%20éducation">Affaires culturelles et éducation</option>
# <option value="Défense">Défense</option>
# <option value="Développement%20durable">Développement durable</option>
# <option value="Affaires%20sociales">Affaires sociales</option>
# </select>
# </div>
# <div class="divCritere">
# 							Famille Socioprof.
# 							<select class="inputCritere" name="critFamilleSociopro">
# <option value="default">Choisissez une option</option>
# <option value="Sans%20profession%20déclarée">Sans profession déclarée</option>
# <option value="Cadres%20et%20professions%20intellectuelles%20supérieures">Cadres et professions intellectuelles supérieures</option>
# <option value="Professions%20Intermédiaires">Professions Intermédiaires</option>
# <option value="Retraités">Retraités</option>
# <option value="Artisans,%20commerçants%20et%20chefs%20d'entreprise">Artisans, commerçants et chefs d'entreprise</option>
# <option value="Autres%20personnes%20sans%20activité%20professionnelle">Autres personnes sans activité professionnelle</option>
# <option value="Employés">Employés</option>
# <option value="Agriculteurs%20exploitants">Agriculteurs exploitants</option>
# <option value="Ouvriers">Ouvriers</option>
# </select>
# </div>
# <div class="divCritere">
# 							Catégorie Socioprof.
# 							<select class="inputCritere" name="critCatSociopro">
# <option value="default">Choisissez une option</option>
# <option value="Sans%20profession%20déclarée">Sans profession déclarée</option>
# <option value="Cadres%20d'entreprise">Cadres d'entreprise</option>
# <option value="Professions%20intermédiaires%20de%20l'enseignement,%20de%20la%20santé,%20de%20la%20fonction%20publique%20et%20assimilés">Professions intermédiaires de l'enseignement, de la santé, de la fonction publique et assimilés</option>
# <option value="Professions%20libérales%20et%20assimilés">Professions libérales et assimilés</option>
# <option value="Cadres%20de%20la%20fonction%20publique,%20professions%20intellectuelles%20et%20%20artistiques">Cadres de la fonction publique, professions intellectuelles et  artistiques</option>
# <option value="Anciens%20cadres%20et%20professions%20intermédiaires">Anciens cadres et professions intermédiaires</option>
# <option value="Chefs%20d'entreprise%20de%2010%20salariés%20ou%20plus">Chefs d'entreprise de 10 salariés ou plus</option>
# <option value="Commerçants%20et%20assimilés">Commerçants et assimilés</option>
# <option value="Anciens%20employés%20et%20ouvriers">Anciens employés et ouvriers</option>
# <option value="Artisans">Artisans</option>
# <option value="Inactifs%20divers%20(autres%20que%20retraités)">Inactifs divers (autres que retraités)</option>
# <option value="Employés%20de%20la%20fonction%20publique">Employés de la fonction publique</option>
# <option value="Agriculteurs%20exploitants">Agriculteurs exploitants</option>
# <option value="Employés%20administratifs%20d'entreprise">Employés administratifs d'entreprise</option>
# <option value="Professions%20intermédiaires%20administratives%20et%20commerciales%20des%20entreprises">Professions intermédiaires administratives et commerciales des entreprises</option>
# <option value="Anciens%20artisans,%20commerçants,%20chefs%20d'entreprise">Anciens artisans, commerçants, chefs d'entreprise</option>
# <option value="Anciens%20agriculteurs%20exploitants">Anciens agriculteurs exploitants</option>
# <option value="Employés%20de%20commerce">Employés de commerce</option>
# <option value="Ouvriers%20qualifiés">Ouvriers qualifiés</option>
# <option value="Ouvriers%20agricoles">Ouvriers agricoles</option>
# <option value="Contremaîtres,%20agents%20de%20maîtrise">Contremaîtres, agents de maîtrise</option>
# </select>
# </div>
# <div class="divCritere">
# 							Département
# 							<select class="inputCritere" name="critDept">
# <option value="default">Choisissez une option</option>
# <option value="Défense">Ain</option>
# <option value="Finances">Isère</option>
# <option value="Finances">Haute-Corse</option>
# <option value="Développement%20durable">Seine-Maritime</option>
# <option value="Affaires%20étrangères">Guyane</option>
# <option value="Développement%20durable">Bouches-du-Rhône</option>
# <option value="Affaires%20économiques">Doubs</option>
# <option value="Lois">Mayotte</option>
# <option value="Affaires%20étrangères">Loire-Atlantique</option>
# <option value="Affaires%20culturelles%20et%20éducation">Seine-Saint-Denis</option>
# <option value="Défense">Français établis hors de France</option>
# <option value="Lois">Drôme</option>
# <option value="Développement%20durable">Charente-Maritime</option>
# <option value="Affaires%20sociales">Moselle</option>
# <option value="Affaires%20économiques">Essonne</option>
# <option value="Affaires%20culturelles%20et%20éducation">Vaucluse</option>
# <option value="Affaires%20culturelles%20et%20éducation">Var</option>
# <option value="Affaires%20étrangères">Paris</option>
# <option value="Affaires%20économiques">Haute-Garonne</option>
# <option value="Finances">Ille-et-Vilaine</option>
# <option value="Défense">Alpes-de-Haute-Provence</option>
# <option value="Développement%20durable">Yvelines</option>
# <option value="Affaires%20étrangères">Finistère</option>
# <option value="Affaires%20sociales">Vienne</option>
# <option value="Développement%20durable">Mayenne</option>
# <option value="Affaires%20sociales">Réunion</option>
# <option value="Défense">Deux-Sèvres</option>
# <option value="Affaires%20économiques">Meurthe-et-Moselle</option>
# <option value="Défense">Aube</option>
# <option value="Défense">Haute-Vienne</option>
# <option value="Finances">Marne</option>
# <option value="Lois">Haut-Rhin</option>
# <option value="Affaires%20sociales">Guadeloupe</option>
# <option value="Affaires%20sociales">Nord</option>
# <option value="Défense">Gard</option>
# <option value="Finances">Côtes-d'Armor</option>
# <option value="Défense">Haute-Saône</option>
# <option value="Finances">Gers</option>
# <option value="Affaires%20économiques">Pas-de-Calais</option>
# <option value="Lois">Aveyron</option>
# <option value="Lois">Calvados</option>
# <option value="Affaires%20sociales">Rhône</option>
# <option value="Affaires%20étrangères">Maine-et-Loire</option>
# <option value="Finances">Oise</option>
# <option value="Affaires%20économiques">Savoie</option>
# <option value="Développement%20durable">Aisne</option>
# <option value="Développement%20durable">Cantal</option>
# <option value="Développement%20durable">Loire</option>
# <option value="Finances">Territoire de Belfort</option>
# <option value="Affaires%20économiques">Hautes-Alpes</option>
# <option value="Défense">Seine-et-Marne</option>
# <option value="Défense">Gironde</option>
# <option value="Défense">Hauts-de-Seine</option>
# <option value="Défense">Alpes-Maritimes</option>
# <option value="Finances">Wallis-et-Futuna</option>
# <option value="Défense">Val-de-Marne</option>
# <option value="Affaires%20culturelles%20et%20éducation">Loir-et-Cher</option>
# <option value="Affaires%20sociales">Polynésie Française</option>
# <option value="Défense">Pyrénées-Atlantiques</option>
# <option value="Développement%20durable">Jura</option>
# <option value="Affaires%20culturelles%20et%20éducation">Ardèche</option>
# <option value="Finances">Vendée</option>
# <option value="Affaires%20culturelles%20et%20éducation">Meuse</option>
# <option value="Affaires%20sociales">Landes</option>
# <option value="Défense">Pyrénées-Orientales</option>
# <option value="Défense">Indre-et-Loire</option>
# <option value="Affaires%20étrangères">Puy-de-Dôme</option>
# <option value="Affaires%20culturelles%20et%20éducation">Dordogne</option>
# <option value="Affaires%20sociales">Vosges</option>
# <option value="Affaires%20culturelles%20et%20éducation">Saint-Pierre-et-Miquelon</option>
# <option value="Défense">Corse-du-Sud</option>
# <option value="Lois">Val-d'Oise</option>
# <option value="Lois">Ardennes</option>
# <option value="Défense">Cher</option>
# <option value="Lois">Saône-et-Loire</option>
# <option value="Développement%20durable">Haute-Marne</option>
# <option value="Lois">Côte-d'Or</option>
# <option value="Affaires%20économiques">Yonne</option>
# <option value="Finances">Lot-et-Garonne</option>
# <option value="Affaires%20économiques">Somme</option>
# <option value="Affaires%20culturelles%20et%20éducation">Hérault</option>
# <option value="Affaires%20sociales">Loiret</option>
# <option value="Affaires%20économiques">Hautes-Pyrénées</option>
# <option value="Finances">Haute-Savoie</option>
# <option value="Affaires%20sociales">Allier</option>
# <option value="Affaires%20étrangères">Nouvelle-Calédonie</option>
# <option value="Affaires%20culturelles%20et%20éducation">Sarthe</option>
# <option value="Finances">Indre</option>
# <option value="Affaires%20sociales">Eure</option>
# <option value="Affaires%20économiques">Manche</option>
# <option value="Développement%20durable">Nièvre</option>
# <option value="Affaires%20sociales">Saint-Barthélemy et Saint-Martin</option>
# <option value="Affaires%20sociales">Aude</option>
# <option value="Développement%20durable">Bas-Rhin</option>
# <option value="Défense">Morbihan</option>
# <option value="Affaires%20culturelles%20et%20éducation">Corrèze</option>
# <option value="Affaires%20économiques">Orne</option>
# <option value="Affaires%20sociales">Eure-et-Loir</option>
# <option value="Affaires%20sociales">Martinique</option>
# <option value="Affaires%20sociales">Charente</option>
# <option value="Affaires%20économiques">Ariège</option>
# <option value="Affaires%20économiques">Creuse</option>
# <option value="Lois">Lozère</option>
# <option value="Finances">Tarn-et-Garonne</option>
# <option value="Affaires%20économiques">Lot</option>
# <option value="Finances">Tarn</option>
# <option value="Affaires%20économiques">Haute-Loire</option>
# </select>
# </div>
# <div class="divCritere">
# 							Région
# 							<select class="inputCritere" name="critRegion">
# <option value="default">Choisissez une option</option>
# <option value="Auvergne-Rhône-Alpes">Auvergne-Rhône-Alpes</option>
# <option value="Corse">Corse</option>
# <option value="Normandie">Normandie</option>
# <option value="Guyane">Guyane</option>
# <option value="Provence-Alpes-Côte%20d'Azur">Provence-Alpes-Côte d'Azur</option>
# <option value="Bourgogne-Franche-Comté">Bourgogne-Franche-Comté</option>
# <option value="Mayotte">Mayotte</option>
# <option value="Pays%20de%20la%20Loire">Pays de la Loire</option>
# <option value="Ile-de-France">Ile-de-France</option>
# <option value="Français%20établis%20hors%20de%20France">Français établis hors de France</option>
# <option value="Nouvelle-Aquitaine">Nouvelle-Aquitaine</option>
# <option value="Grand%20Est">Grand Est</option>
# <option value="Occitanie">Occitanie</option>
# <option value="Bretagne">Bretagne</option>
# <option value="Réunion">Réunion</option>
# <option value="Guadeloupe">Guadeloupe</option>
# <option value="Hauts-de-France">Hauts-de-France</option>
# <option value="Wallis-et-Futuna">Wallis-et-Futuna</option>
# <option value="Centre-Val%20de%20Loire">Centre-Val de Loire</option>
# <option value="Polynésie%20française">Polynésie française</option>
# <option value="Saint-Pierre-et-Miquelon">Saint-Pierre-et-Miquelon</option>
# <option value="Nouvelle-Calédonie">Nouvelle-Calédonie</option>
# <option value="Saint-Barthélemy%20et%20Saint-Martin">Saint-Barthélemy et Saint-Martin</option>
# <option value="Martinique">Martinique</option>
# </select>
# </div>
# <div class="divCritere">
# 							Mandat communal
# 							<select class="inputCritere" name="critMandatCommunal">
# <option value="default">Choisissez une option</option>
# <option value="Conseiller%20municipal">Conseiller municipal</option>
# <option value="Maire">Maire</option>
# <option value="Conseiller%20de%20Paris">Conseiller de Paris</option>
# <option value="Adjoint%20au%20Maire%20d'arrondissement">Adjoint au Maire d'arrondissement</option>
# <option value="Adjoint%20au%20Maire">Adjoint au Maire</option>
# </select>
# </div>
# <div class="divCritere">
# 							Mandat départemental
# 							<select class="inputCritere" name="critMandatDept">
# <option value="default">Choisissez une option</option>
# <option value="Conseiller%20départemental">Conseiller départemental</option>
# <option value="Conseiller%20de%20la%20Métropole%20de%20Lyon">Conseiller de la Métropole de Lyon</option>
# <option value="Vice-président%20">Vice-président </option>
# <option value="Conseiller%20d'Alsace">Conseiller d'Alsace</option>
# </select>
# </div>
# <div class="divCritere">
# 							Mandat régional
# 							<select class="inputCritere" name="critMandatRegional">
# <option value="default">Choisissez une option</option>
# <option value="Conseiller%20régional">Conseiller régional</option>
# <option value="Membre">Membre</option>
# <option value="Vice-président">Vice-président</option>
# </select>
# </div>
# <button class="btn btn-default" type="submit">Lancer la recherche</button>
# <button class="btn btn-default" type="reset">Effacer les critères</button>
# </form>
# <h2>Résultats de la recherche</h2>
# <div id="deputes-list">
# <h2>Liste des députés</h2>
# <table>
# <thead>
# <tr>
# <th>Lien fiche</th>
# <th>Civilité</th>
# <th>Nom</th>
# <th>Prénom</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA605036">M. Damien Abad</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Abad 																									</td>
# <td>
# 																										 Damien 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA719866">Mme Caroline Abadie</a>
# </td>
# <td>
# 																										 Mme 																									</td>
# <td>
# 																										 Abadie 																									</td>
# <td>
# 																										 Caroline 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA719146">M. Jean-Félix Acquaviva</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Acquaviva 																									</td>
# <td>
# 																										 Jean-Félix 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA722038">M. Damien Adam</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Adam 																									</td>
# <td>
# 																										 Damien 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA721036">M. Lénaïck Adam</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Adam 																									</td>
# <td>
# 																										 Lénaïck 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA718954">M. Saïd Ahamada</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Ahamada 																									</td>
# <td>
# 																										 Saïd 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA605963">M. Éric Alauzet</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Alauzet 																									</td>
# <td>
# 																										 Éric 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA724827">Mme Ramlati Ali</a>
# </td>
# <td>
# 																										 Mme 																									</td>
# <td>
# 																										 Ali 																									</td>
# <td>
# 																										 Ramlati 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA720124">Mme Aude Amadou</a>
# </td>
# <td>
# 																										 Mme 																									</td>
# <td>
# 																										 Amadou 																									</td>
# <td>
# 																										 Aude 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA721278">M. Patrice Anato</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Anato 																									</td>
# <td>
# 																										 Patrice 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA721158">M. Pieyre-Alexandre Anglade</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Anglade 																									</td>
# <td>
# 																										 Pieyre-Alexandre 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA719318">Mme Emmanuelle Anthoine</a>
# </td>
# <td>
# 																										 Mme 																									</td>
# <td>
# 																										 Anthoine 																									</td>
# <td>
# 																										 Emmanuelle 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA719100">M. Jean-Philippe Ardouin</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Ardouin 																									</td>
# <td>
# 																										 Jean-Philippe 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA720310">M. Christophe Arend</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Arend 																									</td>
# <td>
# 																										 Christophe 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA721674">Mme Stéphanie Atger</a>
# </td>
# <td>
# 																										 Mme 																									</td>
# <td>
# 																										 Atger 																									</td>
# <td>
# 																										 Stéphanie 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA609726">M. Julien Aubert</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Aubert 																									</td>
# <td>
# 																										 Julien 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA721666">Mme Edith Audibert</a>
# </td>
# <td>
# 																										 Mme 																									</td>
# <td>
# 																										 Audibert 																									</td>
# <td>
# 																										 Edith 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA588884">Mme Clémentine Autain</a>
# </td>
# <td>
# 																										 Mme 																									</td>
# <td>
# 																										 Autain 																									</td>
# <td>
# 																										 Clémentine 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA721624">Mme Laetitia Avia</a>
# </td>
# <td>
# 																										 Mme 																									</td>
# <td>
# 																										 Avia 																									</td>
# <td>
# 																										 Laetitia 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA642764">M. Joël Aviragnet</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Aviragnet 																									</td>
# <td>
# 																										 Joël 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA719770">M. Florian Bachelier</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Bachelier 																									</td>
# <td>
# 																										 Florian 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA718744">Mme Delphine Bagarry</a>
# </td>
# <td>
# 																										 Mme 																									</td>
# <td>
# 																										 Bagarry 																									</td>
# <td>
# 																										 Delphine 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA721776">M. Didier Baichère</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Baichère 																									</td>
# <td>
# 																										 Didier 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA719558">M. Erwan Balanant</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Balanant 																									</td>
# <td>
# 																										 Erwan 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA722082">Mme Françoise Ballet-Blu</a>
# </td>
# <td>
# 																										 Mme 																									</td>
# <td>
# 																										 Ballet-Blu 																									</td>
# <td>
# 																										 Françoise 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA720256">Mme Géraldine Bannier</a>
# </td>
# <td>
# 																										 Mme 																									</td>
# <td>
# 																										 Bannier 																									</td>
# <td>
# 																										 Géraldine 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA642724">M. Frédéric Barbier</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Barbier 																									</td>
# <td>
# 																										 Frédéric 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA721836">M. Jean-Noël Barrot</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Barrot 																									</td>
# <td>
# 																										 Jean-Noël 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA721046">Mme Nathalie Bassire</a>
# </td>
# <td>
# 																										 Mme 																									</td>
# <td>
# 																										 Bassire 																									</td>
# <td>
# ...
# <a href="/deputes/fiche/OMC_PA721968">M. Michel Vialay</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Vialay 																									</td>
# <td>
# 																										 Michel 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA720704">Mme Laurence Vichnievsky</a>
# </td>
# <td>
# 																										 Mme 																									</td>
# <td>
# 																										 Vichnievsky 																									</td>
# <td>
# 																										 Laurence 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA340357">Mme Michèle Victory</a>
# </td>
# <td>
# 																										 Mme 																									</td>
# <td>
# 																										 Victory 																									</td>
# <td>
# 																										 Michèle 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA722102">Mme Annie Vidal</a>
# </td>
# <td>
# 																										 Mme 																									</td>
# <td>
# 																										 Vidal 																									</td>
# <td>
# 																										 Annie 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA607090">M. Jean-Pierre Vigier</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Vigier 																									</td>
# <td>
# 																										 Jean-Pierre 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA331582">M. Philippe Vigier</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Vigier 																									</td>
# <td>
# 																										 Philippe 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA606639">M. Patrick Vignal</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Vignal 																									</td>
# <td>
# 																										 Patrick 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA719512">Mme Corinne Vignon</a>
# </td>
# <td>
# 																										 Mme 																									</td>
# <td>
# 																										 Vignon 																									</td>
# <td>
# 																										 Corinne 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA722260">M. Cédric Villani</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Villani 																									</td>
# <td>
# 																										 Cédric 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA421348">M. André Villiers</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Villiers 																									</td>
# <td>
# 																										 André 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA721474">M. Stéphane Viry</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Viry 																									</td>
# <td>
# 																										 Stéphane 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA721170">M. Stéphane Vojetta</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Vojetta 																									</td>
# <td>
# 																										 Stéphane 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA721262">M. Guillaume Vuilletet</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Vuilletet 																									</td>
# <td>
# 																										 Guillaume 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA2952">M. Jean-Luc Warsmann</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Warsmann 																									</td>
# <td>
# 																										 Jean-Luc 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA720746">M. Sylvain Waserman</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Waserman 																									</td>
# <td>
# 																										 Sylvain 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA2960">M. Éric Woerth</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Woerth 																									</td>
# <td>
# 																										 Éric 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA722268">Mme Martine Wonner</a>
# </td>
# <td>
# 																										 Mme 																									</td>
# <td>
# 																										 Wonner 																									</td>
# <td>
# 																										 Martine 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA722110">M. Hubert Wulfranc</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Wulfranc 																									</td>
# <td>
# 																										 Hubert 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA720318">Mme Hélène Zannier</a>
# </td>
# <td>
# 																										 Mme 																									</td>
# <td>
# 																										 Zannier 																									</td>
# <td>
# 																										 Hélène 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA721864">Mme Souad Zitouni</a>
# </td>
# <td>
# 																										 Mme 																									</td>
# <td>
# 																										 Zitouni 																									</td>
# <td>
# 																										 Souad 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA718962">M. Jean-Marc Zulesi</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Zulesi 																									</td>
# <td>
# 																										 Jean-Marc 																									</td>
# </tr>
# <tr>
# <td>
# <a href="/deputes/fiche/OMC_PA267330">M. Michel Zumkeller</a>
# </td>
# <td>
# 																										 M. 																									</td>
# <td>
# 																										 Zumkeller 																									</td>
# <td>
# 																										 Michel 																									</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# </div>
# </article>
# </div>
# </section>
# </div>
# </div>
# </div>
# <div class="new-style-ezpublish">
# <footer class="site-footer">
# <div class="site-footer--top">
# <div class="site-footer--top-logo"></div>
# <div class="hr-flag-large"></div>
# </div>
# <div class="site-footer--content">
# <div class="container small">
# <div class="container">
# <div class="ha-grid with-divider bloc-first">
# <div class="ha-grid-item size-1-2 bloc-lcp">
# <div class="block-footer-image">
# <div class="">
# <img alt="Logo LCP Assemblée nationale" src="/dyn/assets/images/logos/LCP.png">
# </img></div>
# <div>
#                                     LCP<br><span>Accédez à toute<br/>l'actualité de<br/>la Chaine Parlementaire</span>
# </br></div>
# <a class="inner" href="http://www.lcp.fr/" title="Site web LCP Assemblée nationale"></a>
# </div>
# </div>
# <div class="ha-grid-item size-1-2 bloc-opendata">
# <div class="block-footer-image">
# <div class="">
#                                     OPEN DATA<br/><span>Accédez à toutes<br/>les données de<br/>l'Assemblée nationale</span>
# </div>
# <a class="inner" href="https://data.assemblee-nationale.fr/" title="Site web de l'open data"></a>
# <div class="">
# <span class="an-icons-logo-opendata"></span>
# </div>
# </div>
# </div>
# </div>
# <div class="bloc-second">
# <ul class="social-networks">
# <li>
# <i class="an-icons-twitter"></i>
# <a class="inner" href="https://twitter.com/AssembleeNat" target="_blank"></a>
# </li>
# <li>
# <i class="an-icons-facebook"></i>
# <a class="inner" href="https://fr-fr.facebook.com/AssembleeNationale" target="_blank"></a>
# </li>
# <li>
# <i class="an-icons-instagram"></i>
# <a class="inner" href="https://www.instagram.com/assembleenationale" target="_blank"></a>
# </li>
# <li>
# <i class="an-icons-linkedin2"></i>
# <a class="inner" href="https://fr.linkedin.com/company/assemblee-nationale" target="_blank"></a>
# </li>
# </ul>
# </div>
# <div class="bloc-third">
# <div class="bloc-third-item">
# <div><a href="https://boutique.assemblee-nationale.fr/" title="Accéder au site boutique de l'Assemblée nationale">BOUTIQUE DE L'ASSEMBLEE</a></div>
# <div class="an-icons-chevron-right"></div>
# </div>
# <div class="bloc-third-item link-abonnements-action custom-tippy-theme-abonnements">
# <div class="link-abonnements-action--title">UNE SEMAINE À L'ASSEMBLÉE</div>
# <div class="an-icons-chevron-right"></div>
# </div>
# <div id="template-tippy-abonnements" style="display: none;">
# <!-- Begin Mailchimp Signup Form -->
# <div id="mc_embed_signup abonnements-container">
# <div class="abonnements-container--header">Une semaine à l'Assemblée</div>
# <div class="abonnements-container--description">
# <p>
#                                         Inscrivez-vous à notre lettre <span>Une semaine à l'Assemblée</span> et recevez tous
#                                         les vendredis dans votre messagerie les temps forts de l'actualité de la semaine à venir !
#                                     </p>
# <p>
#                                         Votre adresse de messagerie est uniquement utilisée pour vous envoyer les lettres de l'Assemblée nationale.
#                                         Vous pouvez à tout moment utiliser le lien de désabonnement intégré dans la lettre.
#                                         <a href="https://www.assemblee-nationale.fr/faq.asp">En savoir plus sur la gestion de vos données et de vos droits</a>
# </p>
# </div>
# <form action="https://assemblee-nationale.us19.list-manage.com/subscribe/post?u=faad0c0d61d56141e601169c5&amp;id=aa7e617bea" class="validate abonnements-container--form" id="mc-embedded-subscribe-form" method="post" name="mc-embedded-subscribe-form" novalidate="" target="_blank">
# <div class="abonnements-container--form-container" id="mc_embed_signup_scroll">
# <input class="email" id="mce-EMAIL" name="EMAIL" placeholder="Adresse e-mail" required="" type="email" value=""/>
# <!-- real people should not fill this in and expect good things - do not remove this or risk form bot signups-->
# <div aria-hidden="true" style="position: absolute; left: -5000px;"><input name="b_faad0c0d61d56141e601169c5_aa7e617bea" tabindex="-1" type="text" value=""/></div>
# <div class="clear"><input class="button" id="mc-embedded-subscribe" name="subscribe" type="submit" value="OK"/></div>
# </div>
# </form>
# </div>
# <!--End mc_embed_signup-->
# </div>
# <div class="bloc-third-item">
# <div><a href="https://www.assemblee-nationale.fr/abonnement.asp" title="S'abonner aux services en ligne">S'ABONNER À UN SERVICE</a></div>
# <div class="an-icons-chevron-right"></div>
# </div>
# </div>
# <div class="bloc-fourth">
#                         ©Tous droits réservés Assemblée nationale 2019 |
#                         <a href="https://www.assemblee-nationale.fr/faq.asp" title="Accéder aux mentions légales de l'Assemblée nationale">Mentions légales</a> | <a href="https://www.assemblee-nationale.fr/faq.asp" title="Contacter le webmestre">Contacter le webmestre</a> | <a href="https://www.assemblee-nationale.fr/rss/" title="Accéder aux fils RSS">Fils RSS</a>
# <div>Assemblée nationale - 126 Rue de l'Université, 75355 Paris 07 SP - Standard 01 40 63 60 00</div>
# </div>
# </div>
# </div>
# </div>
# </footer>
# </div>
# <script charset="utf-8" src="/extension/common/design/an/javascript/superfish-1.5.1.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/common/design/an/javascript/jwplayer-6.12/jwplayer.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/common/design/an/javascript/chosen.jquery-0.9.12.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/common/design/an/javascript/perfect-scrollbar-0.4.5.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/common/design/an/javascript/jquery.dataTables.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/common/design/an/javascript/jquery.dataTables.pagination.bstrap.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/ezswidl-pskn/design/ezswidl-pskn/javascript/an-front-loader.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/ezswidl-users/design/standard/javascript/ezswidl-users.userregister.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/ezswidl-users/design/standard/javascript/ezswidl-users.ezhumancaptcha.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/ansearch/design/an/javascript/recherche.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/common/design/an/javascript/bootstrap-2.1.1.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/ezswidl-anobjects/design/an/javascript/bootstrap-accessibility.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/common/design/an/javascript/jquery.easing.1.3.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/common/design/an/javascript/jquery.mousewheel.3.1.6.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/common/design/an/javascript/jquery.jscrollpane.2.0.0beta11.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/common/design/an/javascript/jquery.bxSlider.4.1.2.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/common/design/an/javascript/jquery-ui-1.8.21.custom.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/ezswidl-pskn/design/ezswidl-pskn/javascript/libs/jquery.ui.datepicker-fr.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/ezswidl-pskn/design/ezswidl-pskn/javascript/an-front-main.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/ezswidl-anobjects/design/ezflow/javascript/ezswidl-anobjects.deputes.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/ezswidl-anobjects/design/an/javascript/ezswidl-anobjects.dossiers.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/common/design/an/javascript/common.js" type="text/javascript"></script>
# <script charset="utf-8" src="/extension/common/design/an/javascript/captcha.js" type="text/javascript"></script>
# <script type="text/javascript">
#     $matomoSiteId2 = '5';
#     $matomoDomain2 = 'assemblee-nationale.fr';
# </script>
# <!-- Matomo -->
# <script type="text/javascript">
#         var _paq = window._paq = window._paq || [];
#         /* tracker methods like "setCustomDimension" should be called before "trackPageView" */
#         _paq.push(['setDocumentTitle', document.domain + "/" + document.title]);
#         _paq.push(['setCookieDomain', '*.' + $matomoDomain2]);
#         _paq.push(["setDomains", ['*.' + $matomoDomain2]]);
#         _paq.push(["setDoNotTrack", true]);
#         // Call disableCookies before calling trackPageView
#         _paq.push(['disableCookies']);
#         _paq.push(['trackPageView']);
#         _paq.push(['enableLinkTracking']);
#         (function() {
#             var u="https://assembleenationale.matomo.cloud/";
#             _paq.push(['setTrackerUrl', u+'matomo.php']);
#             _paq.push(['setSiteId', $matomoSiteId2]);
#             var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
#             g.type='text/javascript'; g.async=true; g.src='//cdn.matomo.cloud/assembleenationale.matomo.cloud/matomo.js'; s.parentNode.insertBefore(g,s);
#         })();
#     </script>
# <!-- End Matomo Code -->
# <script src="/dyn/assets/js/libs/jquery.nicescroll.min.js"></script>
# <script src="/dyn/assets/js/libs/jquery.mark.min.js"></script>
# <script src="/dyn/js/compiled/main_shared.js"></script>
# </div>
# </body>
# </html>

# %%
# Getting the details into lists

mps = pd.DataFrame(columns=['Name', 'Surname', 'Party', 'URL'])
mpurls =[]
mpnames = []
mpsurnames = []
mpparties = []

for rows in soup.find_all('tr')[1:]: # skip the row with headers
    mpurls.append('https://www2.assemblee-nationale.fr' + rows.find_all('td')[0].find('a', href=True)['href'] + '#deputes-contact')
    mpsurnames.append(rows.find_all('td')[2].get_text().strip())
    mpnames.append(rows.find_all('td')[3].get_text().strip())

# %%
# Combining the lists into a dataframe

mps = pd.DataFrame(
    {'Name': mpnames,
     'Surname': mpsurnames,
     'URL': mpurls
    })

mps.sample(3) # does the dataframe look as it should
# Out:
#          Name          Surname  \
# 193    Michel           Fanget
# 133  François  Cornut-Gentille
# 352  Emmanuel           Maquet
#
#                                                    URL
# 193  https://www2.assemblee-nationale.fr/deputes/fi...
# 133  https://www2.assemblee-nationale.fr/deputes/fi...
# 352  https://www2.assemblee-nationale.fr/deputes/fi...

# %%
mpurls[4] # are the URLs functional?
# Out:
# 'https://www2.assemblee-nationale.fr/deputes/fiche/OMC_PA721036#deputes-contact'

# %%
mps.count() # Is the number of parliament members correct?
# Out:
# Name       570
# Surname    570
# URL        570
# dtype: int64

# %%
www = "https://www2.assemblee-nationale.fr/deputes/fiche/OMC_PA721036#deputes-contact"
soup = BeautifulSoup(requests.get(www).text)
soup.select(".twitter")
# Out:
# [<a class="twitter topmargin" href="https://twitter.com/@LenaickADAM/">Consulter le compte Twitter de M. Lénaïck Adam <img src="/extension/ezswidl-pskn/design/ezswidl-pskn/images/icone-twitter.png"/></a>]

# %% [markdown]
# The problem could be solved by downloading personal pages: https://stackoverflow.com/questions/1825438/download-html-page-and-its-contents#1825465

# %% [markdown]
# # Locating twitter handle in personal pages

# %%
twitters = []
for www in mps['URL']:
    soup = BeautifulSoup(requests.get(www).text)
    
    try:
        twt = soup.find('a', attrs={'class':'twitter'}, href=True)['href']
    except:
        twt = ''
    twt = twt.replace("https://twitter.com/", "")
    twitters.append(twt)

mps['TwitterHandle'] = twitters

# %%
mps.sample(5)
# Out:
#           Name          Surname  \
# 488    Laurent     Saint-Martin
# 118       Dino          Cinieri
# 295   Jean-Luc         Lagleize
# 133   François  Cornut-Gentille
# 255  Alexandre          Holroyd
#
#                                                    URL      TwitterHandle
# 488  https://www2.assemblee-nationale.fr/deputes/fi...
# 118  https://www2.assemblee-nationale.fr/deputes/fi...      @DinoCinieri/
# 295  https://www2.assemblee-nationale.fr/deputes/fi...  @jeanluclagleize/
# 133  https://www2.assemblee-nationale.fr/deputes/fi...
# 255  https://www2.assemblee-nationale.fr/deputes/fi...     @alexIholroyd/

# %% [markdown]
# # Cleaning up

# %%
# cleaning all the rubbish I found looking at the data

dirty_strings = ["/", "@"]

for dirt in dirty_strings:
    mps["TwitterHandle"] = mps["TwitterHandle"].str.replace(dirt, "")

# %%
mps.sample(5)
# Out:
#          Name    Surname                                                URL  \
# 554   Patrick     Vignal  https://www2.assemblee-nationale.fr/deputes/fi...
# 291    Daniel  Labaronne  https://www2.assemblee-nationale.fr/deputes/fi...
# 273     Régis    Juanico  https://www2.assemblee-nationale.fr/deputes/fi...
# 320  Sandrine    Le Feur  https://www2.assemblee-nationale.fr/deputes/fi...
# 147  Typhanie     Degois  https://www2.assemblee-nationale.fr/deputes/fi...
#
#        TwitterHandle
# 554
# 291  LabaronneDaniel
# 273          juanico
# 320
# 147  Typhanie_Degois

# %% [markdown]
# Testing with known rubbish handles

# %%
mps.to_csv("FrenchPols.csv")
